# %% [markdown]
# 1. A. Artificial Intelligence
# 2. A. A. ML is a subset of AI, and Deep Learning is a subset of ML
# 3. B. Managing Python/R distributions and packages for data science
# 4. B. python app.py
# 5. B. .ipynb
# 6. B. On Google's cloud servers
# 7.
# 8. B. value_2
# 9. C. complex
# 10. B. <class 'float'>
# 11. B. False
# 12. B. 15
# 13. B. //
# 14. B. 1
# 15. B. !=
# 16. B. ell
# 17. B. Converts string to uppercase
# 18. B. 12
# 19. A. f"Value is {x}"
# 20. B. -1

# %% [markdown]
# 21. B. elif
# 22. A. A
# 23. C. and
# 24. B. False
# 25. B. Exits the loop entirely
# 26. B. Skips the rest of the current iteration and moves to the next
# 27. A. 0 1 2
# 28. B. Acts as a placeholder that does nothing
# 29. A. [2, 4, 6, 8]
# 30. B. 0 to 4
# 31. C. Both A and B
# 32. B. [1, 2, 3, [4, 5]]
# 33. B. extend()
# 34. B. [1, 1, 3, 4, 5]
# 35. B. They are immutable
# 36. B. 3
# 37. B. dict.get(key)
# 38. A. ['a', 'b']
# 39. B. [1, 2, 3]
# 40. B. 9
# 41. B. The purpose and usage of the function
# 42. C. 15
# 43. B. A function calling itself to solve a smaller instance of the problem
# 44. B. lambda
# 45. B. [2, 4, 6]
# 46. C. finally
# 47. B. Raises an AssertionError if the given condition is False
# 48. B. One or more digits
# 49. C. "a"
# 50. B. csv
# 51. B. Pass a variable number of keyword arguments as a dictionary
# 52. B. To modify or extend the behavior of a function without changing its code
# 53. B. Bundling data and methods within a class and restricting direct access to some components
# 54. C. Inheritance
# 55. B. Bark

# %% [markdown]
# 56. B. NumPy
# 57. A. (4,)
# 58. B. [2 4 6]
# 59. B. Change the shape/dimensions of an array without changing its data
# 60. B. 3.5
# 61. B. np.std()
# 62. B. Series
# 63. A. pd.read_csv()
# 64. B. df.describe()
# 65. A. .loc[] uses label-based indexing, .iloc[] uses integer position-based indexing
# 66. B. df.dropna()
# 67. B. df.fillna()
# 68. B. Split data into groups based on a column and apply aggregate functions
# 69. B. df.apply()
# 70. B. 6
# 71. B. Matplotlib
# 72. B. plt.plot()
# 73. B. plt.subplots()
# 74. B. Matplotlib
# 75. B. distplot / histplot
# 76. B. heatmap

# %% [markdown]
# 77. B. The instantaneous rate of change of the function at that point
# 78. B. 2x
# 79. B. Differentiating a composite function (a function within a function)
# 80. C. Zero
# 81. B. Minimize a cost/loss function by iteratively updating parameters
# 82. A. The rate of change of the function with respect to one variable, holding others constant
# 83. B. A vector containing partial derivatives with respect to each variable
# 84. B. The identity matrix
# 85.
# 86.
# 87. B. The set of all possible outcomes of a random experiment
# 88. B. Update the probability of a hypothesis based on new evidence
# 89.
# 90. A. The number of successes in a fixed number of independent Bernoulli trials
# 91. B. It describes the relative likelihood of the variable taking a given value, with probability found via area under the curve
# 92. B. The number of standard deviations a data point is from the mean
# 93. B. The linear relationship and strength/direction between two continuous variables
# 94. B. Approach a normal distribution regardless of the population's original distribution
# 95. B. The sample size is small and the population standard deviation is unknown
# 96. B. The distribution has a long tail on the right side
# 97. B. Make non-normal data more closely approximate a normal distribution
# 98. B. Evaluate model performance on unseen data to check generalization
# 99. B. The average squared difference between predicted and actual values
# 100. B. The model explains a large proportion of the variance in the dependent variable
